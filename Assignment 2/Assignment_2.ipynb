# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Real estate.csv', encoding='latin-1')
df.dropna()
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
print(df.columns)
print(df.index)
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')
# RangeIndex(start=0, stop=414, step=1)

# %%
#Took X5 latitude & X6 longitude as an example

print(df['X5 latitude'], "\n" , "-------------------------------------------------")

print(df[['X5 latitude','X6 longitude']])
# Out:
# 0      24.98298
# 1      24.98034
# 2      24.98746
# 3      24.98746
# 4      24.97937
#          ...
# 409    24.94155
# 410    24.97433
# 411    24.97923
# 412    24.96674
# 413    24.97433
# Name: X5 latitude, Length: 414, dtype: float64
#  -------------------------------------------------
#      X5 latitude  X6 longitude
# 0       24.98298     121.54024
# 1       24.98034     121.53951
# 2       24.98746     121.54391
# 3       24.98746     121.54391
# 4       24.97937     121.54245
# ..           ...           ...
# 409     24.94155     121.50381
# 410     24.97433     121.54310
# 411     24.97923     121.53986
# 412     24.96674     121.54067
# 413     24.97433     121.54310
#
# [414 rows x 2 columns]

# %%
x1 = sns.lineplot(x=df['X2 house age'], y=df['Y house price of unit area']);


print(x1)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
x2 = sns.barplot(x=df['X3 distance to the nearest MRT station'], y=df['Y house price of unit area']);

print(x2)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
x3 = sns.regplot(x=df['X1 transaction date'], y=df['Y house price of unit area']);

print(x3)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
x4 = sns.scatterplot(x=df['X4 number of convenience stores'], y=df['Y house price of unit area']);

print(x4)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df.hist(figsize=(20,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f46cb8bcbd0>,
# ...
#       dtype=object)

# %%
plt.plot( df["X4 number of convenience stores"] ,df["Y house price of unit area"],'g') 
plt.plot(df["X1 transaction date"],df["Y house price of unit area"],'r')

# %%
plt.plot( df["X4 number of convenience stores"] ,df["Y house price of unit area"],'b') 
plt.plot(df["X2 house age"],df["Y house price of unit area"],'c')
